# %% [markdown]
# <a href="https://colab.research.google.com/github/Gulwalishah/Cluster-/blob/main/Probability_and_Statistics_in_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Central Limit Theorem**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm
#import utils

# %% [markdown]
# ***Gaussian population***:  When our population follows a Gaussian distribution

# %%
mu= 10
sigma=5
gaussian_population=np.random.normal(mu,sigma,678040)

# %% [markdown]
# The population has mean 10 and standard deviation is 5

# %%
sns.histplot(gaussian_population,stat="density")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Sampling** from the **population**: if we could not know the value of μ and σ, we could get very close estimates of the true values

# %%
from re import I

gaussian_pop_mean=np.mean(gaussian_population)
gaussian_pop_std=np.std(gaussian_population)
print(f"Gaussian population has mean: {gaussian_pop_mean:.1f} and std: {gaussian_pop_std:.1f}")
# Out:
# Gaussian population has mean: 10.0 and std: 5.0

# %% [markdown]
# Averaging samples out of the population, for this the sample_means can be defined:

# %%
def sample_means(data, sample_size):
  #save all the means in a list
  means=[]
  # For a big number of samples
  # This value does not impact the theorm but how nicely the histograms will look (more sample= better looks)
  for _ in range(10_000):

    #Get a sample of the data WITH replacement
    sample=np.random.choice(data,size=sample_size)

    #save the mean of the sample
    means.append(np.mean)(500)

# Return the mean within a numpy array
    return np.array(means)

# %%
import numpy as np
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt

# Define your data and parameters (e.g., gaussian_population, mu, sigma)

def sample_means(data, sample_size):
    # Save all the means in a list
    means = []

    # For a big number of samples
    # This value does not impact the theorem but how nicely the histograms will look (more samples = better looking)
    for _ in range(10_000):
        # Get a sample of the data WITH replacement
        sample = np.random.choice(data, size=sample_size)

        # Save the mean of the sample
        means.append(np.mean(sample))

    # Return the means within a numpy array
    return np.array(means)

# Compute the sample means
gaussian_sample_means = sample_means(gaussian_population, sample_size=5)

# Plot a histogram of the sample means
sns.histplot(gaussian_sample_means, stat="density",color="lightblue")
plt.show()

# Compute estimated mu
mu_sample_means = mu

# Compute estimated sigma
# 5 is being used because you used a sample size of 5
sigma_sample_means = sigma / np.sqrt(5)

# Define the x-range for the Gaussian curve (this is just for plotting purposes)
x_range = np.linspace(min(gaussian_sample_means), max(gaussian_sample_means), 100)

# Plot everything together
sns.histplot(gaussian_sample_means, stat="density", color="lightblue")
plt.plot(
    x_range,
    norm.pdf(x_range, loc=mu_sample_means, scale=sigma_sample_means),
    color="yellow",
)
plt.show()

# %%
# Histogram of sample means (blue)
sns.histplot(gaussian_sample_means, stat="density", label="hist")

# Estimated PDF of sample means (red)
sns.kdeplot(
    data=gaussian_sample_means,
    color="crimson",
    label="kde",
    linestyle="dashed",
    fill=True,
)

# Gaussian curve with estimated mu and sigma (black)
plt.plot(
    x_range,
    norm.pdf(x_range, loc=mu_sample_means, scale=sigma_sample_means),
    color="black",
    label="gaussian",
)

plt.legend()
plt.show()
